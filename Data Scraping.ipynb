# %%
import os
import pandas as pd

# Folder path
folder_path = 'unsup'

# Initialize a list to store the data
data = []

# Loop through all files in the folder
for file in os.listdir(folder_path):
    # Check if the file is a text file
    if file.endswith('.txt'):
        file_path = os.path.join(folder_path, file)
        
        # Read the content of the file
        with open(file_path, 'r') as file:
            comments = file.readlines()
            
            # Add each line as a row in the data list
            for comment in comments:
                data.append({'Comment': comment.strip()})

# Create a DataFrame
df = pd.DataFrame(data)

df
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
#                                                  Comment
# 0      A newspaperman (Johnny Twennies) living in the...
# 1      As co-founder of Nicko & Joe's Bad Film Club S...
# 2      Very good film from director Wyler, although i...
# 3      This flick will pass the time, and Kurt Russle...
# 4      The Feeding is a terrible werewolf movie about...
# ...                                                  ...
# 49995  I'll keep this short. <br /><br />Most of what...
# ...

# %%
sampled_df = df.sample(n=1400)

# %%
csv_file_path = '1400_cleaned.csv'
sampled_df.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## Manually Labeled Data (1 Category)

# %%
data_1cat = pd.read_csv('data_1cat.csv')
data_1cat
# Out:
#                                                 Comment  \
# 0     This is an unfortunate film. One of its bigges...
# 1     Sometimes something sounds good, but the bare ...
# 2     A complete cult film in Spain.<br /><br />I th...
# 3     Some thoughts (for whatever they are worth)- <...
# 4     I saw that film when i studied films in englan...
# ...                                                 ...
# 1395  i have seen this film a few times but have nev...
# 1396  One of the earliest Japanese animation films I...
# 1397  I found this movie an insult to the southern c...
# 1398  Katrina (Emily Barcley) is a sad, pathetic, ut...
# 1399  I could not believe the good reviews that I sa...
#
#                   Category 1
# 0     Directional Techniques
# 1     Directional Techniques
# 2     Directional Techniques
# 3     Directional Techniques
# 4     Directional Techniques
# ...                      ...
# 1395                    Plot
# 1396           Visual Effect
# ...

# %% [markdown]
# ## Manually Labeled data (3 Category)

# %%
data_3cat = pd.read_csv('data_3cat.csv')
data_3cat
# Out:
#                                                 Comment  \
# 0     This is an unfortunate film. One of its bigges...
# 1     Sometimes something sounds good, but the bare ...
# 2     A complete cult film in Spain.<br /><br />I th...
# 3     Some thoughts (for whatever they are worth)- <...
# 4     I saw that film when i studied films in englan...
# ...                                                 ...
# 1395  i have seen this film a few times but have nev...
# 1396  One of the earliest Japanese animation films I...
# 1397  I found this movie an insult to the southern c...
# 1398  Katrina (Emily Barcley) is a sad, pathetic, ut...
# 1399  I could not believe the good reviews that I sa...
#
#                   Category 1              Category 2 Category 3
# 0     Directional Techniques           Visual Effect        NaN
# 1     Directional Techniques                     NaN        NaN
# 2     Directional Techniques                     NaN        NaN
# ...
